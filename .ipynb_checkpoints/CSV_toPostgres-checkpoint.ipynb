# %%
# Imports
import pandas as pd

# SQLAlchemy Engine Configuration documentation: https://docs.sqlalchemy.org/en/14/core/engines.html#database-urls
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# config.py file needed to hold PostgreSQL password
from config import db_password

# Default DBAPI for the PostgreSQL dialect
import psycopg2

# %%
# Load in the Arabica bean data
arabica_df = pd.read_csv(
    "arabica_cleaned_data.csv"
)

# %%
arabica_df.head()
# Out:
#    Quality_Score  Species                     Owner Country of Origin  \
# 0          90.58  Arabica                 metad plc          Ethiopia
# 1          89.92  Arabica                 metad plc          Ethiopia
# 2          89.75  Arabica  Grounds for Health Admin         Guatemala
# 3          89.00  Arabica       Yidnekachew Dabessa          Ethiopia
# 4          88.83  Arabica                 metad plc          Ethiopia
#
#                                  Company       Altitude  \
# 0      METAD Agricultural Developmet plc      1950-2200
# 1      METAD Agricultural Developmet plc      1950-2200
# 2                                    NaN  1600 - 1800 m
# 3  Yidnekachew Debessa Coffee Plantation      1800-2200
# 4      METAD Agricultural Developmet plc      1950-2200
#
#                      Region                               Producer  \
# 0         GUJI-HAMBELA/GOYO                              METAD PLC
# 1        GUJI-HAMBELA/ALAKA                              METAD PLC
# 2                   Unknown                                    NaN
# 3                    Oromia  Yidnekachew Dabessa Coffee Plantation
# 4  GUJI-HAMBELA/BISHAN FUGU                              METAD PLC
#
#    Number of Bags                  In-Country Partner  ... Clean Cup  \
# 0             300  METAD Agricultural Development plc  ...      10.0
# 1             300  METAD Agricultural Development plc  ...      10.0
# 2               5        Specialty Coffee Association  ...      10.0
# 3             320  METAD Agricultural Development plc  ...      10.0
# 4             300  METAD Agricultural Development plc  ...      10.0
#
#   Sweetness Cupper Points Total Cup Points Moisture  Category One Defects  \
# 0      10.0          8.75    Sample  90.58      12%        0 full defects
# 1      10.0          8.58    Sample  89.92      12%        0 full defects
# 2      10.0          9.25    Sample  89.75       0%        0 full defects
# 3      10.0          8.67    Sample  89.00      11%        0 full defects
# 4      10.0          8.58    Sample  88.83      12%        0 full defects
#
#    Color  Category Two Defects                  Certification Body  date_diff
# 0  Green        0 full defects  METAD Agricultural Development plc        365
# 1  Green        1 full defects  METAD Agricultural Development plc        365
# 2   None        0 full defects        Specialty Coffee Association        365
# 3  Green        2 full defects  METAD Agricultural Development plc        365
# 4  Green        2 full defects  METAD Agricultural Development plc        365
#
# [5 rows x 32 columns]

# %%
# Drop unneeded company data
arabica_df.drop(columns=['Company', 'Producer', 'In-Country Partner', 'Harvest Year'], inplace=True)
arabica_df.head()
# Out:
#    Quality_Score  Species                     Owner Country of Origin  \
# 0          90.58  Arabica                 metad plc          Ethiopia
# 1          89.92  Arabica                 metad plc          Ethiopia
# 2          89.75  Arabica  Grounds for Health Admin         Guatemala
# 3          89.00  Arabica       Yidnekachew Dabessa          Ethiopia
# 4          88.83  Arabica                 metad plc          Ethiopia
#
#         Altitude                    Region  Number of Bags Grading Date  \
# 0      1950-2200         GUJI-HAMBELA/GOYO             300   2015-04-04
# 1      1950-2200        GUJI-HAMBELA/ALAKA             300   2015-04-04
# 2  1600 - 1800 m                   Unknown               5   2010-05-31
# 3      1800-2200                    Oromia             320   2015-03-26
# 4      1950-2200  GUJI-HAMBELA/BISHAN FUGU             300   2015-04-04
#
#    Variety     Status  ... Clean Cup  Sweetness  Cupper Points  \
# 0    Other  Completed  ...      10.0       10.0           8.75
# 1    Other  Completed  ...      10.0       10.0           8.58
# 2  Bourbon  Completed  ...      10.0       10.0           9.25
# 3    Other  Completed  ...      10.0       10.0           8.67
# 4    Other  Completed  ...      10.0       10.0           8.58
#
#    Total Cup Points  Moisture  Category One Defects  Color  \
# 0     Sample  90.58       12%        0 full defects  Green
# 1     Sample  89.92       12%        0 full defects  Green
# 2     Sample  89.75        0%        0 full defects   None
# 3     Sample  89.00       11%        0 full defects  Green
# 4     Sample  88.83       12%        0 full defects  Green
#
#    Category Two Defects                  Certification Body  date_diff
# 0        0 full defects  METAD Agricultural Development plc        365
# 1        1 full defects  METAD Agricultural Development plc        365
# 2        0 full defects        Specialty Coffee Association        365
# 3        2 full defects  METAD Agricultural Development plc        365
# 4        2 full defects  METAD Agricultural Development plc        365
#
# [5 rows x 28 columns]

# %%
# Drop unneeded production data
arabica_df.drop(columns=['Variety', 'Processing Method', 'Color', 'Number of Bags', 'Grading Date', 'Status', 'date_diff'], inplace=True)
arabica_df.head()
# Out:
#    Quality_Score  Species                     Owner Country of Origin  \
# 0          90.58  Arabica                 metad plc          Ethiopia
# 1          89.92  Arabica                 metad plc          Ethiopia
# 2          89.75  Arabica  Grounds for Health Admin         Guatemala
# 3          89.00  Arabica       Yidnekachew Dabessa          Ethiopia
# 4          88.83  Arabica                 metad plc          Ethiopia
#
#         Altitude                    Region  Aroma  Flavor  Aftertaste  \
# 0      1950-2200         GUJI-HAMBELA/GOYO   8.67    8.83        8.67
# 1      1950-2200        GUJI-HAMBELA/ALAKA   8.75    8.67        8.50
# 2  1600 - 1800 m                   Unknown   8.42    8.50        8.42
# 3      1800-2200                    Oromia   8.17    8.58        8.42
# 4      1950-2200  GUJI-HAMBELA/BISHAN FUGU   8.25    8.50        8.25
#
#    Acidity  ...  Balance  Uniformity  Clean Cup  Sweetness  Cupper Points  \
# 0     8.75  ...     8.42        10.0       10.0       10.0           8.75
# 1     8.58  ...     8.42        10.0       10.0       10.0           8.58
# 2     8.42  ...     8.42        10.0       10.0       10.0           9.25
# 3     8.42  ...     8.25        10.0       10.0       10.0           8.67
# 4     8.50  ...     8.33        10.0       10.0       10.0           8.58
#
#    Total Cup Points Moisture Category One Defects Category Two Defects  \
# 0     Sample  90.58      12%       0 full defects       0 full defects
# 1     Sample  89.92      12%       0 full defects       1 full defects
# 2     Sample  89.75       0%       0 full defects       0 full defects
# 3     Sample  89.00      11%       0 full defects       2 full defects
# 4     Sample  88.83      12%       0 full defects       2 full defects
#
#                    Certification Body
# 0  METAD Agricultural Development plc
# 1  METAD Agricultural Development plc
# 2        Specialty Coffee Association
# 3  METAD Agricultural Development plc
# 4  METAD Agricultural Development plc
#
# [5 rows x 21 columns]

# %%
# Drop unneeded certification data
arabica_df.drop(columns=['Quality_Score', 'Category One Defects', 'Category Two Defects', 'Certification Body'], inplace=True)
arabica_df.head()
# Out:
#    Species                     Owner Country of Origin       Altitude  \
# 0  Arabica                 metad plc          Ethiopia      1950-2200
# 1  Arabica                 metad plc          Ethiopia      1950-2200
# 2  Arabica  Grounds for Health Admin         Guatemala  1600 - 1800 m
# 3  Arabica       Yidnekachew Dabessa          Ethiopia      1800-2200
# 4  Arabica                 metad plc          Ethiopia      1950-2200
#
#                      Region  Aroma  Flavor  Aftertaste  Acidity  Body  \
# 0         GUJI-HAMBELA/GOYO   8.67    8.83        8.67     8.75  8.50
# 1        GUJI-HAMBELA/ALAKA   8.75    8.67        8.50     8.58  8.42
# 2                   Unknown   8.42    8.50        8.42     8.42  8.33
# 3                    Oromia   8.17    8.58        8.42     8.42  8.50
# 4  GUJI-HAMBELA/BISHAN FUGU   8.25    8.50        8.25     8.50  8.42
#
#    Balance  Uniformity  Clean Cup  Sweetness  Cupper Points Total Cup Points  \
# 0     8.42        10.0       10.0       10.0           8.75    Sample  90.58
# 1     8.42        10.0       10.0       10.0           8.58    Sample  89.92
# 2     8.42        10.0       10.0       10.0           9.25    Sample  89.75
# 3     8.25        10.0       10.0       10.0           8.67    Sample  89.00
# 4     8.33        10.0       10.0       10.0           8.58    Sample  88.83
#
#   Moisture
# 0      12%
# 1      12%
# 2       0%
# 3      11%
# 4      12%

# %%
# Rename columns to remove spaces
arabica_df.rename(columns={ 
    'Country of Origin': 'countryOfOrigin',
    'Clean Cup': 'cleanCup',
    'Cupper Points': 'cupperPoints',
    'Total Cup Points': 'totalCupPoints'
}, inplace=True)
arabica_df.head()
# Out:
#    Species                     Owner countryOfOrigin       Altitude  \
# 0  Arabica                 metad plc        Ethiopia      1950-2200
# 1  Arabica                 metad plc        Ethiopia      1950-2200
# 2  Arabica  Grounds for Health Admin       Guatemala  1600 - 1800 m
# 3  Arabica       Yidnekachew Dabessa        Ethiopia      1800-2200
# 4  Arabica                 metad plc        Ethiopia      1950-2200
#
#                      Region  Aroma  Flavor  Aftertaste  Acidity  Body  \
# 0         GUJI-HAMBELA/GOYO   8.67    8.83        8.67     8.75  8.50
# 1        GUJI-HAMBELA/ALAKA   8.75    8.67        8.50     8.58  8.42
# 2                   Unknown   8.42    8.50        8.42     8.42  8.33
# 3                    Oromia   8.17    8.58        8.42     8.42  8.50
# 4  GUJI-HAMBELA/BISHAN FUGU   8.25    8.50        8.25     8.50  8.42
#
#    Balance  Uniformity  cleanCup  Sweetness  cupperPoints totalCupPoints  \
# 0     8.42        10.0      10.0       10.0          8.75  Sample  90.58
# 1     8.42        10.0      10.0       10.0          8.58  Sample  89.92
# 2     8.42        10.0      10.0       10.0          9.25  Sample  89.75
# 3     8.25        10.0      10.0       10.0          8.67  Sample  89.00
# 4     8.33        10.0      10.0       10.0          8.58  Sample  88.83
#
#   Moisture
# 0      12%
# 1      12%
# 2       0%
# 3      11%
# 4      12%

# %%
# Load in the Robusta bean data
robusta_df = pd.read_csv(
    "robusta_cleaned_data.csv"
)

# %%
robusta_df.head()
# Out:
#    Quality_Score  Species                         Owner Country of Origin  \
# 0          83.75  Robusta  Ankole coffee producers coop            Uganda
# 1          83.50  Robusta                Nishant Gurjer             India
# 2          83.25  Robusta                 Andrew Hetzel             India
# 3          83.00  Robusta                        UGACOF            Uganda
# 4          83.00  Robusta  Katuka Development Trust Ltd            Uganda
#
#                             Farm Name                       Company  \
# 0       Kyangundu cooperative society  Ankole Coffee Producers Coop
# 1      Sethuraman Estate Kaapi Royale                  Kaapi Royale
# 2                   Sethuraman Estate             Sethuraman Estate
# 3                 UGACOF project area                    UGACOF Ltd
# 4  Katikamu capca farmers association  Katuka Development Trust Ltd
#
#     Altitude                       Region                      Producer  \
# 0       1488         Sheema South Western  Ankole coffee producers coop
# 1       3170  Chikmagalur Karnataka Indua   Nishant Gurjer Kaapi Royale
# 2      1000m                  Chikmagalur                Nishant Gurjer
# 3       1212                      Central                        UGACOF
# 4  1200-1300        Luwero central region  Katuka Development Trust Ltd
#
#    Number of Bags  ... Clean Cup Balance Cupper Points Total Cup Points  \
# 0             300  ...      10.0    7.92          8.00    Sample  83.75
# 1             320  ...      10.0    7.92          8.00    Sample  83.50
# 2             300  ...      10.0    7.92          8.00    Sample  83.25
# 3             320  ...      10.0    7.75          8.08    Sample  83.00
# 4               1  ...      10.0    7.75          7.67    Sample  83.00
#
#   Moisture Category One Defects  Color  Category Two Defects  \
# 0     12 %       0 full defects  Green        2 full defects
# 1      0 %       0 full defects    NaN        2 full defects
# 2      0 %       0 full defects  Green        0 full defects
# 3     12 %       0 full defects  Green        7 full defects
# 4     12 %       0 full defects  Green        3 full defects
#
#                     Certification Body  date_diff
# 0  Uganda Coffee Development Authority        365
# 1         Specialty Coffee Association        365
# 2         Specialty Coffee Association        365
# 3  Uganda Coffee Development Authority        365
# 4  Uganda Coffee Development Authority        365
#
# [5 rows x 33 columns]

# %%
# Drop unneeded company data
robusta_df.drop(columns=['Company', 'Producer', 'In-Country Partner', 'Harvest Year', 'Farm Name'], inplace=True)
robusta_df.head()
# Out:
#    Quality_Score  Species                         Owner Country of Origin  \
# 0          83.75  Robusta  Ankole coffee producers coop            Uganda
# 1          83.50  Robusta                Nishant Gurjer             India
# 2          83.25  Robusta                 Andrew Hetzel             India
# 3          83.00  Robusta                        UGACOF            Uganda
# 4          83.00  Robusta  Katuka Development Trust Ltd            Uganda
#
#     Altitude                       Region  Number of Bags Grading Date  \
# 0       1488         Sheema South Western             300   2014-06-26
# 1       3170  Chikmagalur Karnataka Indua             320   2017-10-31
# 2      1000m                  Chikmagalur             300   2015-04-30
# 3       1212                      Central             320   2014-07-14
# 4  1200-1300        Luwero central region               1   2014-06-26
#
#   Variety     Status  ... Clean Cup  Balance  Cupper Points  Total Cup Points  \
# 0   Other  Completed  ...      10.0     7.92           8.00     Sample  83.75
# 1   Other  Completed  ...      10.0     7.92           8.00     Sample  83.50
# 2   Other  Completed  ...      10.0     7.92           8.00     Sample  83.25
# 3   Other  Completed  ...      10.0     7.75           8.08     Sample  83.00
# 4   Other  Completed  ...      10.0     7.75           7.67     Sample  83.00
#
#    Moisture  Category One Defects  Color  Category Two Defects  \
# 0      12 %        0 full defects  Green        2 full defects
# 1       0 %        0 full defects    NaN        2 full defects
# 2       0 %        0 full defects  Green        0 full defects
# 3      12 %        0 full defects  Green        7 full defects
# 4      12 %        0 full defects  Green        3 full defects
#
#                     Certification Body  date_diff
# 0  Uganda Coffee Development Authority        365
# 1         Specialty Coffee Association        365
# 2         Specialty Coffee Association        365
# 3  Uganda Coffee Development Authority        365
# 4  Uganda Coffee Development Authority        365
#
# [5 rows x 28 columns]

# %%
# Drop unneeded production data
robusta_df.drop(columns=['Variety', 'Processing Method', 'Color', 'Number of Bags', 'Grading Date', 'Status', 'date_diff'], inplace=True)
robusta_df.head()
# Out:
#    Quality_Score  Species                         Owner Country of Origin  \
# 0          83.75  Robusta  Ankole coffee producers coop            Uganda
# 1          83.50  Robusta                Nishant Gurjer             India
# 2          83.25  Robusta                 Andrew Hetzel             India
# 3          83.00  Robusta                        UGACOF            Uganda
# 4          83.00  Robusta  Katuka Development Trust Ltd            Uganda
#
#     Altitude                       Region  Aroma  Flavor  Aftertaste  Acidity  \
# 0       1488         Sheema South Western   7.83    8.08        7.75     7.92
# 1       3170  Chikmagalur Karnataka Indua   8.00    7.75        7.92     8.00
# 2      1000m                  Chikmagalur   7.92    7.83        7.92     8.00
# 3       1212                      Central   8.00    7.92        7.92     7.75
# 4  1200-1300        Luwero central region   8.33    7.83        7.83     7.75
#
#    ...  Body  Uniformity  Clean Cup  Balance  Cupper Points  Total Cup Points  \
# 0  ...  8.25        10.0       10.0     7.92           8.00     Sample  83.75
# 1  ...  7.92        10.0       10.0     7.92           8.00     Sample  83.50
# 2  ...  7.83        10.0       10.0     7.92           8.00     Sample  83.25
# 3  ...  7.83        10.0       10.0     7.75           8.08     Sample  83.00
# 4  ...  8.25        10.0       10.0     7.75           7.67     Sample  83.00
#
#   Moisture Category One Defects Category Two Defects  \
# 0     12 %       0 full defects       2 full defects
# 1      0 %       0 full defects       2 full defects
# 2      0 %       0 full defects       0 full defects
# 3     12 %       0 full defects       7 full defects
# 4     12 %       0 full defects       3 full defects
#
#                     Certification Body
# 0  Uganda Coffee Development Authority
# 1         Specialty Coffee Association
# 2         Specialty Coffee Association
# 3  Uganda Coffee Development Authority
# 4  Uganda Coffee Development Authority
#
# [5 rows x 21 columns]

# %%
# Drop unneeded certification data
robusta_df.drop(columns=['Quality_Score', 'Category One Defects', 'Category Two Defects', 'Certification Body'], inplace=True)
robusta_df.head()
# Out:
#    Species                         Owner Country of Origin   Altitude  \
# 0  Robusta  Ankole coffee producers coop            Uganda       1488
# 1  Robusta                Nishant Gurjer             India       3170
# 2  Robusta                 Andrew Hetzel             India      1000m
# 3  Robusta                        UGACOF            Uganda       1212
# 4  Robusta  Katuka Development Trust Ltd            Uganda  1200-1300
#
#                         Region  Aroma  Flavor  Aftertaste  Acidity  Sweetness  \
# 0         Sheema South Western   7.83    8.08        7.75     7.92       8.00
# 1  Chikmagalur Karnataka Indua   8.00    7.75        7.92     8.00       8.00
# 2                  Chikmagalur   7.92    7.83        7.92     8.00       7.83
# 3                      Central   8.00    7.92        7.92     7.75       7.75
# 4        Luwero central region   8.33    7.83        7.83     7.75       7.58
#
#    Body  Uniformity  Clean Cup  Balance  Cupper Points Total Cup Points  \
# 0  8.25        10.0       10.0     7.92           8.00    Sample  83.75
# 1  7.92        10.0       10.0     7.92           8.00    Sample  83.50
# 2  7.83        10.0       10.0     7.92           8.00    Sample  83.25
# 3  7.83        10.0       10.0     7.75           8.08    Sample  83.00
# 4  8.25        10.0       10.0     7.75           7.67    Sample  83.00
#
#   Moisture
# 0     12 %
# 1      0 %
# 2      0 %
# 3     12 %
# 4     12 %

# %%
# Rename columns to remove spaces
robusta_df.rename(columns={  
    'Country of Origin': 'countryOfOrigin',
    'Clean Cup': 'cleanCup',
    'Cupper Points': 'cupperPoints',
    'Total Cup Points': 'totalCupPoints'
}, inplace=True)
robusta_df.head()
# Out:
#    Species                         Owner countryOfOrigin   Altitude  \
# 0  Robusta  Ankole coffee producers coop          Uganda       1488
# 1  Robusta                Nishant Gurjer           India       3170
# 2  Robusta                 Andrew Hetzel           India      1000m
# 3  Robusta                        UGACOF          Uganda       1212
# 4  Robusta  Katuka Development Trust Ltd          Uganda  1200-1300
#
#                         Region  Aroma  Flavor  Aftertaste  Acidity  Sweetness  \
# 0         Sheema South Western   7.83    8.08        7.75     7.92       8.00
# 1  Chikmagalur Karnataka Indua   8.00    7.75        7.92     8.00       8.00
# 2                  Chikmagalur   7.92    7.83        7.92     8.00       7.83
# 3                      Central   8.00    7.92        7.92     7.75       7.75
# 4        Luwero central region   8.33    7.83        7.83     7.75       7.58
#
#    Body  Uniformity  cleanCup  Balance  cupperPoints totalCupPoints Moisture
# 0  8.25        10.0      10.0     7.92          8.00  Sample  83.75     12 %
# 1  7.92        10.0      10.0     7.92          8.00  Sample  83.50      0 %
# 2  7.83        10.0      10.0     7.92          8.00  Sample  83.25      0 %
# 3  7.83        10.0      10.0     7.75          8.08  Sample  83.00     12 %
# 4  8.25        10.0      10.0     7.75          7.67  Sample  83.00     12 %

# %%
# Create connection to database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/CoffeeDB"
    
# Create the database engine
engine = create_engine(db_string)
conn = engine.connect()

# %%
# Save the data from dataframe to
# postgres table "ArabicaRatings"
arabica_df.to_sql(
    'ArabicaRatings', con=conn,
    if_exists='replace',
    index=True
)

conn = psycopg2.connect(db_string
                        )
conn.autocommit = True
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# UndefinedTable: relation "sqlite_master" does not exist
# LINE 1: SELECT name FROM sqlite_master WHERE type='table' AND name=?...
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /var/folders/8n/zdm6k1yn3qd5qnvqbcwhjd8m0000gn/T/ipykernel_15591/4105237370.py in <module>
#       4     'ArabicaRatings', con=conn,
#       5     if_exists='replace',
# ----> 6     index=True
#       7 )
#       8
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2223             dtype=dtype,
#    2224         )
# -> 2225         table.create()
#    2226         table.insert(chunksize, method)
#    2227
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     854
#     855     def create(self):
# --> 856         if self.exists():
#     857             if self.if_exists == "fail":
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in exists(self)
#     838
#     839     def exists(self):
# --> 840         return self.pd_sql.has_table(self.name, self.schema)
#     841
#     842     def sql_schema(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    2234         query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
#    2235
# -> 2236         return len(self.execute(query, [name]).fetchall()) > 0
#    2237
#    2238     def get_table(self, table_name: str, schema: str | None = None):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': relation "sqlite_master" does not exist
# LINE 1: SELECT name FROM sqlite_master WHERE type='table' AND name=?...
#                          ^

# %%
# Save the data from dataframe to
# postgres table "RobustaRatings"
robusta_df.to_sql(
    'RobustaRatings', con=conn,
    if_exists='replace',
    index=True
)

conn = psycopg2.connect(db_string
                        )
conn.autocommit = True
cursor = conn.cursor()

# conn.commit()
conn.close()
